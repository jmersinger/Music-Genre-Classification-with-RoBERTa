# %%
import torch
# Set the device
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f'Using device: {device}')

# Optionally allocate a fraction of GPU memory
torch.cuda.set_per_process_memory_fraction(0.9, 0)

# Check memory stats
print(f'Allocated GPU memory: {torch.cuda.memory_allocated(device) / (1024 ** 3):.2f} GB')
print(f'Reserved GPU memory: {torch.cuda.memory_reserved(device) / (1024 ** 3):.2f} GB')
# Out:
# Using device: cuda
# Allocated GPU memory: 0.00 GB
# Reserved GPU memory: 0.00 GB

# %%
from data.cleaning import download_and_clean

artists, tracks = download_and_clean()

# %%
print(artists.head())
# Out:
#                          id  ...  popularity
# 45   0VLMVnVbJyJ4oyZs2L3Yl2  ...           6
# 46   0dt23bs4w8zx154C5xdVyl  ...           5
# 47   0pGhoB99qpEJEsBQxgaskQ  ...           7
# 48   3HDrX2OtSuXLW5dLR85uN3  ...           6
# 136  22mLrN5fkppmuUPsHx6i2G  ...           3
#
# [5 rows x 5 columns]

# %%
print(tracks.head())
# Out:
#                        id  ...                                             genres
# 2  07A5yehtSnoedViJAZkNnc  ...                             [tango, vintage tango]
# 3  08FmqUhxtyLTn6pAh6bk45  ...                             [tango, vintage tango]
# 4  08y9GfoqCWfOGsKdwojr5e  ...  [adult standards, big band, swing, easy listen...
# 5  0BRXJHRNGQ3W4v9frnSfhu  ...  [adult standards, big band, swing, easy listen...
# 7  0IA0Hju8CAgYfV1hwhidBH  ...                                  [vintage chanson]
#
# [5 rows x 21 columns]

# %%
from itertools import chain
all_genres = set(chain.from_iterable(tracks["genres"]))
len(all_genres)
# all_genres
# Out:
# 4706

# %%
genre_to_index = {genre: idx for idx, genre in enumerate(sorted(all_genres))}
# genre_to_index

print(all_genres)
print(genre_to_index)
# Out:
# {'finnish folk', 'lithuanian pop', 'singaporean singer-songwriter', 'swedish metalcore', 'danish jazz', 'lgbtq+ hip hop', 'alternative pop', 'full on', 'chill beats', 'german jazz', 'deep space rock', 'dreamo', 'sad rap', 'suomirap', 'shakuhachi', 'slovenian rock', 'bard', 'mollywood', 'nashville indie', 'french romanticism', 'filthstep', 'svensk indie', 'atmospheric post-rock', 'drone rock', 'outlaw country', 'zespol dzieciecy', 'pibroch', 'early romantic era', 'classic portuguese pop', 'classical trumpet', 'kurdish rock', 'vintage french electronic', 'spacewave', 'british comedy', 'kayokyoku', 'microhouse', 'australian comedy', 'epicore', 'vapor pop', 'indonesian death metal', 'slc indie', 'classic norwegian pop', 'jig and reel', 'german metal', 'polish black metal', 'trap baiano', 'dutch punk', 'shojo', 'south african country', 'trap carioca', 'string folk', 'dutch tech house', 'neo classical metal', 'rock keyboard', 'atlanta indie', 'turkish pop', 'electronica', 'indian edm', 'rumba congolaise', 'cincinnati rap', 'zim urban groove', 'celtic harp', 'dream pop', 'slovenian hip hop', 'messianic praise', 'new orleans jazz', 'old school uk hip hop', 'progressive doom', 'long island punk', 'xinyao', 'orlando indie', 'future garage', 'dub brasileiro', 'dirty south rap', 'japanese vgm', 'neue deutsche welle', 'musica mocambicana', 'norwegian rock', 'organic ambient', 'dark disco', 'folclore tucumano', 'taiwan rock', 'new jersey indie', 'gaita', 'turkish instrumental', 'industrial rock', 'modern folk rock', 'vintage swing', 'kwaito', 'sydney indie', 'contemporary post-bop', 'christmas instrumental', 'nuevo tango', 'canterbury scene', 'lldm', 'classical guitar', 'canadian latin', 'musica piemonteisa', 'dakke dak', 'bedroom pop', 'uk contemporary r&b', 'persian traditional', 'russian power metal', 'classic sinhala pop', 'acoustic rock', 'north carolina indie', 'new jersey hardcore', 'italo house', 'tango cancion', 'trad quebecois', 'ecuadorian pop', 'italian orchestra', 'swedish garage rock', 'fake', 'telugu worship', 'thai idol', 'southeast asian post-rock', 'christian hard rock', 'bhojpuri pop', 'french pop', 'gothic black metal', 'panpipe', 'brazilian hardcore', 'azeri pop', 'vintage old-time', 'straight-ahead jazz', 'gothic post-punk', 'virginia punk', 'namibian pop', 'gothic alternative', 'pinoy singer-songwriter', 'minneapolis indie', 'japanese edm', 'lounge house', 'pop violin', 'swiss hip hop', 'musica pernambucana', 'japanese concert band', 'doo-wop', 'italian tech house', 'copla', 'starogradska', 'bebop', 'serbian electronic', 'juju', 'cantopop', 'polish post-punk', 'french oi', 'cape town indie', 'gospel rap', 'german alternative rock', 'bass trip', 'granada indie', 'italian emo', 'atlanta metal', 'korean city pop', 'indie pop rock', 'modern enka', 'venezuelan hip hop', 'yodeling', 'bomba y plena', 'jug band', 'grand rapids indie', 'utapri', 'bulgarian hip hop', 'louvor', 'tamil pop', 'polynesian traditional', 'uk drill', 'comedy', 'downtempo', 'highlife', 'texas blues', 'ska revival', 'neapolitan funk', 'spanish rockabilly', 'banda carnavalera', 'hip hop cubano', 'second line', 'indie veneto', 'taiwan hip hop', 'malawian pop', 'diy pop punk', 'desi pop', 'hamburg hip hop', 'vintage italian pop', 'blues rock', 'indonesian metal', 'rock tico', 'mexican hip hop', 'k-pop', 'musica sul-mato-grossense', 'classic persian pop', 'french garage rock', 'rap cristao', 'uk tech house', 'experimental indie rock', 'kosovan pop', 'nightcore', 'sunshine pop', 'deep italo disco', 'grim death metal', 'gamecore', 'swiss techno', 'reunion pop', 'classical cello', 'cuatro venezolano', 'blaskapelle', 'vintage norwegian pop', 'classify', 'african percussion', 'twee indie pop', 'anthem emo', 'chamber folk', 'j-reggae', 'german thrash metal', 'singaporean punk', 'colombian electronic', 'norwegian hip hop', 'irish electronic', 'glitchcore', 'palestinian pop', 'indian jazz', 'polish folk', 'sesame street', 'afrobeat brasileiro', 'vgm instrumental',  ...
# {'21st century classical': 0, '432hz': 1, '48g': 2, 'a cappella': 3, 'a3': 4, 'abstract': 5, 'abstract beats': 6, 'abstract hip hop': 7, 'abstract idm': 8, 'accordeon': 9, 'accordion': 10, 'acid house': 11, 'acid jazz': 12, 'acid rock': 13, 'acid techno': 14, 'acid trance': 15, 'acidcore': 16, 'acousmatic': 17, 'acoustic blues': 18, 'acoustic chill': 19, 'acoustic guitar cover': 20, 'acoustic opm': 21, 'acoustic pop': 22, 'acoustic punk': 23, 'acoustic rock': 24, 'action rock': 25, 'adoracao': 26, 'adoracion': 27, 'adult standards': 28, 'adventista': 29, 'afghan pop': 30, 'afghan traditional': 31, 'african electronic': 32, 'african experimental': 33, 'african gospel': 34, 'african metal': 35, 'african percussion': 36, 'african reggae': 37, 'african rock': 38, 'african-american classical': 39, 'afrikaans': 40, 'afrikaans folk': 41, 'afrikaans gospel': 42, 'afro dancehall': 43, 'afro house': 44, 'afro psych': 45, 'afro r&b': 46, 'afro soul': 47, 'afro-cuban traditional': 48, 'afro-funk': 49, 'afrobeat': 50, 'afrobeat brasileiro': 51, 'afrobeat fusion': 52, 'afrofuturism': 53, 'afrofuturismo brasileiro': 54, 'afropop': 55, 'afroswing': 56, 'aggro chileno': 57, 'aggrotech': 58, 'ai': 59, 'aikatsu': 60, 'ainu folk': 61, 'alabama indie': 62, 'alabama metal': 63, 'alabama rap': 64, 'alaska indie': 65, 'albanian hip hop': 66, 'albanian pop': 67, 'alberta country': 68, 'album rock': 69, 'albuquerque indie': 70, 'algerian folk': 71, 'alpine yodeling': 72, 'alt z': 73, 'alt-idol': 74, 'alte': 75, 'alternative americana': 76, 'alternative ccm': 77, 'alternative country': 78, 'alternative dance': 79, 'alternative emo': 80, 'alternative hardcore': 81, 'alternative hip hop': 82, 'alternative metal': 83, 'alternative metalcore': 84, 'alternative pop': 85, 'alternative pop rock': 86, 'alternative r&b': 87, 'alternative rock': 88, 'alternative roots rock': 89, 'amapiano': 90, 'ambeat': 91, 'ambient': 92, 'ambient black metal': 93, 'ambient folk': 94, 'ambient fusion': 95, 'ambient house': 96, 'ambient idm': 97, 'ambient industrial': 98, 'ambient pop': 99, 'ambient psychill': 100, 'ambient techno': 101, 'ambient trance': 102, 'ambient worship': 103, 'american choir': 104, 'american classical piano': 105, 'american contemporary classical': 106, 'american early music': 107, 'american folk revival': 108, 'american grindcore': 109, 'american metalcore': 110, 'american modern classical': 111, 'american oi': 112, 'american orchestra': 113, 'american post-rock': 114, 'american primitive': 115, 'american romanticism': 116, 'american shoegaze': 117, 'amharic pop': 118, 'anadolu rock': 119, 'anarcho-punk': 120, 'ancient mediterranean': 121, 'andean flute': 122, 'anglican liturgy': 123, 'animal singing': 124, 'anime': 125, 'anime latino': 126, 'anime rock': 127, 'anime score': 128, 'ann arbor indie': 129, 'anthem': 130, 'anthem emo': 131, 'anthem worship': 132, 'anti-folk': 133, 'antideutsche': 134, 'antilliaanse rap': 135, 'antiviral pop': 136, 'appalachian folk': 137, 'arab alternative': 138, 'arab electronic': 139, 'arab folk': 140, 'arab groove': 141, 'arab metal': 142, 'arab pop': 143, 'arab trap': 144, 'arabesk': 145, 'arabic hip hop': 146, 'arabic jazz': 147, 'argentine alternative rock': 148, 'argentine ambient': 149, 'argentine hardcore': 150, 'argentine heavy metal': 151, 'argentine hip hop': 152, 'argentine indie': 153, 'argentine indie rock': 154, 'argentine jazz': 155, 'argentine metal': 156, 'argentine punk': 157, 'argentine reggae': 158, 'argentine rock': 159, 'argentine telepop': 160, 'arizona punk': 161, 'arkansas country': 162, 'arkansas hip hop': 163, 'arkansas indie': 164, 'armenian folk': 165, 'armenian hip hop': 166, 'armenian pop': 167, 'arpa paraguaya': 168, 'art pop': 169, 'art punk': 170, 'art rock': 171, 'art song': 172, 'asakaa': 173, 'asbury park indie': 174, 'asheville indie': 175, 'asian american hip hop': 176, 'asmr': 177, 'assamese pop': 178, 'assyrian pop': 179, 'athens indie': 180, 'atl hip hop': 181, 'atl trap': 182, 'at ...

# %%
from sklearn import preprocessing
import numpy as np

labelEncoded = preprocessing.LabelEncoder()

arr = np.asarray(tracks["genres"])
unique = {}

i = 0

nested_lst_of_tuples = [tuple(l) for l in arr]

for elem in nested_lst_of_tuples:
    if elem not in unique:
        unique[elem] = i
        i = i + 1

coded = []
for elem in nested_lst_of_tuples:
    coded.append(unique[elem])
# Out:
# Accuracy:  0.03843148255755706
# Recall:  0.2115322976804458
# F1 Score:  0.008495640418688255

# %%
from sklearn.model_selection import train_test_split

inputs = tracks[["popularity", "duration_ms", "explicit", "danceability", "energy", "key", "loudness", "mode",
                "speechiness", "acousticness", "instrumentalness", "liveness", "valence", "tempo", "time_signature"]]
outputs = coded
X_train, X_test, y_train, y_test = train_test_split(inputs, outputs, test_size=0.1, random_state=42)

# %%
from sklearn.naive_bayes import GaussianNB
classifier = GaussianNB()

classifier.fit(X_train, y_train)

y_pred = classifier.predict(X_test)

# %%
from sklearn import metrics

print("Accuracy: ", metrics.accuracy_score(y_test, y_pred))
print("Recall: ", metrics.recall_score(y_test, y_pred, average='macro', zero_division=1))
print("F1 Score: ", metrics.f1_score(y_test, y_pred, average='macro'))
